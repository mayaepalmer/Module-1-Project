# %% [markdown]
# <a href="https://colab.research.google.com/github/mayaepalmer/Module-1-Project/blob/main/Module_1_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('melbourne_housing.csv')
df.head()
# Out:
#        Suburb           Address  Rooms Type    Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000     VB  Nelson
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  3/12/2016       2.5      3067         2         1  1.0       202
# 1   4/2/2016       2.5      3067         2         1  0.0       156
# 2   4/3/2017       2.5      3067         3         2  0.0       134
# 3   4/3/2017       2.5      3067         3         2  1.0        94
# 4   4/6/2016       2.5      3067         3         1  2.0       120
#
#    BuildingArea  YearBuilt CouncilArea             Regionname  Propertycount
# ...

# %% [markdown]
# Question 1 & 2

# %%
sns.scatterplot(x='Landsize', y='Price', data=df, hue='Type')
plt.show()

# %% [markdown]
# Question 3 & 4

# %%
average_price = df[['YearBuilt', 'Price']].groupby('YearBuilt').mean()
average_price

average_price = df[['YearBuilt', 'Price']].groupby('YearBuilt', as_index=False).mean()
average_price

plt.plot(average_price['YearBuilt'], average_price['Price'])

plt.show()
#average_price = df['Price'].mean()

#sns.lineplot(x='YearBuilt', y= average_price , data=df)
#plt.show()

# %% [markdown]
# Question 5 & 6

# %%
#average_with_region = df[['Regionname', 'Price']].groupby('Regionname').mean()
#average_with_region

#average_with_region = df[['Regionname', 'Price']].groupby('Regionname', as_index=False).mean()
#average_with_region

#plt.plot(average_with_region['Regionname'], average_with_region['Price'])

#plt.show()
plt.figure(figsize=(12, 10))
sns.barplot(x='Regionname', y='Price', data=df)#, hue='Regionname')
plt.show()

# %% [markdown]
# Question 7 & 8

# %%
sns.histplot(x='Price', data=df)
plt.show()

# %% [markdown]
# Question 9, 10, & 11

# %%
sns.boxplot(x='YearBuilt', y='Regionname', data=df, orient='h')
plt.show()
